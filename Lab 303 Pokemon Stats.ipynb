# %%
import pandas as pd
import numpy as np

# %%
pokemon = pd.read_csv("pokemon.csv")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
display(pokemon.head(10))
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
import re

# %%
pokemon.columns
list(pokemon.columns)

for col in pokemon.columns:
     # do something with a column name;
    print(col)
# Out:
# #
# Name
# Type 1
# Type 2
# Total
# HP
# Attack
# Defense
# Sp. Atk
# Sp. Def
# Speed
# Generation
# Legendary

# %%
# %%time
# this returns an iterable index object
pokemon.index
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# RangeIndex(start=0, stop=800, step=1)

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
pokemon[['Name', 'Type 1', 'Type 2']]
# Out:
#                       Name   Type 1  Type 2
# 0                Bulbasaur    Grass  Poison
# 1                  Ivysaur    Grass  Poison
# 2                 Venusaur    Grass  Poison
# 3    VenusaurMega Venusaur    Grass  Poison
# 4               Charmander     Fire     NaN
# ..                     ...      ...     ...
# 795                Diancie     Rock   Fairy
# 796    DiancieMega Diancie     Rock   Fairy
# 797    HoopaHoopa Confined  Psychic   Ghost
# 798     HoopaHoopa Unbound  Psychic    Dark
# 799              Volcanion     Fire   Water
#
# [800 rows x 3 columns]

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pokemon['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
pokemon.Name = pokemon.Name.apply(lambda x: re.sub(r'(.+)(Mega.+)',r'\2', x))
pokemon.Name = pokemon.Name.apply(lambda x: re.sub(r'(.+)(Prima1.+)',r'\2', x))
pokemon.Name = pokemon.Name.apply(lambda x: re.sub(r'(HoopaHoopa)(.+)','Hoopa'+r'\2', x))

# %%
print(pd.concat([pokemon['Type 1'], pokemon['Type 2']]).unique())
len(pd.concat([pokemon['Type 1'], pokemon['Type 2']]).unique())
# Out:
# ['Grass' 'Fire' 'Water' 'Bug' 'Normal' 'Poison' 'Electric' 'Ground'
#  'Fairy' 'Fighting' 'Psychic' 'Rock' 'Ghost' 'Ice' 'Dragon' 'Dark' 'Steel'
#  'Flying' '']
# 19

# %%
display(sorted(dict(pokemon['Type 1'].value_counts()).items()))

display(sorted(dict(pokemon['Type 2'].value_counts()).items()))
# Out:
# [('Bug', 69),
#  ('Dark', 31),
#  ('Dragon', 32),
#  ('Electric', 44),
#  ('Fairy', 17),
#  ('Fighting', 27),
#  ('Fire', 52),
#  ('Flying', 4),
#  ('Ghost', 32),
#  ('Grass', 70),
#  ('Ground', 32),
#  ('Ice', 24),
#  ('Normal', 98),
#  ('Poison', 28),
#  ('Psychic', 57),
#  ('Rock', 44),
#  ('Steel', 27),
#  ('Water', 112)]
# [('', 386),
#  ('Bug', 3),
#  ('Dark', 20),
#  ('Dragon', 18),
#  ('Electric', 6),
#  ('Fairy', 23),
#  ('Fighting', 26),
#  ('Fire', 12),
#  ('Flying', 97),
#  ('Ghost', 14),
#  ('Grass', 25),
#  ('Ground', 35),
#  ('Ice', 14),
#  ('Normal', 4),
#  ('Poison', 34),
#  ('Psychic', 33),
#  ('Rock', 14),
#  ('Steel', 22),
#  ('Water', 14)]

# %%
print(len(pokemon))
type_columns = ['Type 1', 'Type 2']
types = pokemon[type_columns].drop_duplicates()
display(types)
# Out:
# 800
#       Type 1  Type 2
# 0      Grass  Poison
# 4       Fire
# 6       Fire  Flying
# 7       Fire  Dragon
# 9      Water
# ..       ...     ...
# 778    Ghost   Grass
# 790   Flying  Dragon
# 797  Psychic   Ghost
# 798  Psychic    Dark
# 799     Fire   Water
#
# [154 rows x 2 columns]

# %%
pokemon
# Out:
#        #            Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1       Bulbasaur    Grass  Poison    318  45      49       49
# 1      2         Ivysaur    Grass  Poison    405  60      62       63
# 2      3        Venusaur    Grass  Poison    525  80      82       83
# 3      3   Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4      Charmander     Fire            309  39      52       43
# ..   ...             ...      ...     ...    ...  ..     ...      ...
# 795  719         Diancie     Rock   Fairy    600  50     100      150
# 796  719    Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  Hoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   Hoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721       Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# ...

# %%
pokemon['A/D Ratio'] = pokemon['Attack']/pokemon['Defense']
pokemon
# Out:
#        #            Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1       Bulbasaur    Grass  Poison    318  45      49       49
# 1      2         Ivysaur    Grass  Poison    405  60      62       63
# 2      3        Venusaur    Grass  Poison    525  80      82       83
# 3      3   Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4      Charmander     Fire            309  39      52       43
# ..   ...             ...      ...     ...    ...  ..     ...      ...
# 795  719         Diancie     Rock   Fairy    600  50     100      150
# 796  719    Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  Hoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   Hoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721       Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# ...

# %%
pokemon_ad = pokemon['A/D Ratio'].idxmax()
pokemon_max_ad = pokemon.loc[pokemon_ad]
print(pokemon_max_ad)
# Out:
# #                            386
# Name          DeoxysAttack Forme
# Type 1                   Psychic
# Type 2
# Total                        600
# HP                            50
# Attack                       180
# Defense                       20
# Sp. Atk                      180
# Sp. Def                       20
# Speed                        150
# Generation                     3
# Legendary                   True
# A/D Ratio                    9.0
# Combo Type              Psychic
# Name: 429, dtype: object

# %%
pokemon_ad2 = pokemon['A/D Ratio'].idxmin()
pokemon_min_ad = pokemon.loc[pokemon_ad2]
print(pokemon_min_ad)
# Out:
# #                  213
# Name           Shuckle
# Type 1             Bug
# Type 2            Rock
# Total              505
# HP                  20
# Attack              10
# Defense            230
# Sp. Atk             10
# Sp. Def            230
# Speed                5
# Generation           2
# Legendary        False
# A/D Ratio     0.043478
# Name: 230, dtype: object

# %%
pokemon['Type 2'] = pokemon['Type 2'].fillna('')
pokemon['Combo Type'] = pokemon['Type 1'] + (' ' + pokemon['Type 2']).fillna(' ')
pokemon
# Out:
#        #            Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1       Bulbasaur    Grass  Poison    318  45      49       49
# 1      2         Ivysaur    Grass  Poison    405  60      62       63
# 2      3        Venusaur    Grass  Poison    525  80      82       83
# 3      3   Mega Venusaur    Grass  Poison    625  80     100      123
# 4      4      Charmander     Fire            309  39      52       43
# ..   ...             ...      ...     ...    ...  ..     ...      ...
# 795  719         Diancie     Rock   Fairy    600  50     100      150
# 796  719    Mega Diancie     Rock   Fairy    700  50     160      110
# 797  720  Hoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720   Hoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721       Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio     Combo Type
# ...

# %%
pokemon_top_ratio = pokemon.nlargest(5, 'A/D Ratio')
pokemon_top_ratio
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic            600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock            350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000    Psychic
# 347       65       20     65           3      False      4.500  Water Dark
# 19        15       80    145           1      False      3.750  Bug Poison
# 453       30       30     58           4      False      3.125       Rock
# 348       95       40     95           3      False      3.000  Water Dark

# %%
pokemon['Combo Type'] = np.where(pokemon['Type 2'].isna(), pokemon['Type 1'], pokemon['Type 1']+'-'+pokemon['Type 2'])
pokemon.head()

# pokemon_avg = pokemon.groupby('Combo Type').mean(numeric_only=True).reset_index()
# pokemon_avg[pokemon_avg['Combo Type'].isin(pokemon_top_ratio)]
# pokemon_avg
# Out:
#    #           Name Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  \
# 0  1      Bulbasaur  Grass  Poison    318  45      49       49       65
# 1  2        Ivysaur  Grass  Poison    405  60      62       63       80
# 2  3       Venusaur  Grass  Poison    525  80      82       83      100
# 3  3  Mega Venusaur  Grass  Poison    625  80     100      123      122
# 4  4     Charmander   Fire            309  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  A/D Ratio    Combo Type
# 0       65     45           1      False   1.000000  Grass-Poison
# 1       80     60           1      False   0.984127  Grass-Poison
# 2      100     80           1      False   0.987952  Grass-Poison
# 3      120     80           1      False   0.813008  Grass-Poison
# 4       50     65           1      False   1.209302         Fire-

# %%
pokemon_sorted = pokemon.sort_values(by=['A/D Ratio'], ascending=False)
top_poke_list = pokemon_sorted.head(5)
top_poke_list
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic            600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock            350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000    Psychic-
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125       Rock-
# 348       95       40     95           3      False      3.000  Water-Dark

# %%
combo_list = list(top_poke_list['Combo Type'].unique())
combo_list
# Out:
# ['Psychic-', 'Water-Dark', 'Bug-Poison', 'Rock-']

# %%
top_combos = pokemon_sorted.iloc[0:5]

combo_types = top_combos['Combo Type'].unique()
list_combotypes = list(combo_types)

top_combos
# Out:
#        #                Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 429  386  DeoxysAttack Forme  Psychic            600  50     180       20
# 347  318            Carvanha    Water    Dark    305  45      90       20
# 19    15       Mega Beedrill      Bug  Poison    495  65     150       40
# 453  408            Cranidos     Rock            350  67     125       40
# 348  319            Sharpedo    Water    Dark    460  70     120       40
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio  Combo Type
# 429      180       20    150           3       True      9.000    Psychic-
# 347       65       20     65           3      False      4.500  Water-Dark
# 19        15       80    145           1      False      3.750  Bug-Poison
# 453       30       30     58           4      False      3.125       Rock-
# 348       95       40     95           3      False      3.000  Water-Dark

# %%
poke_mean = pokemon_sorted.groupby('Combo Type').agg('mean').reset_index()
poke_mean
# Out:
# C:\Users\harri\AppData\Local\Temp\ipykernel_14528\463658210.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   poke_mean = pokemon_sorted.groupby('Combo Type').agg('mean').reset_index()
#         Combo Type           #       Total         HP      Attack     Defense  \
# 0             Bug-  361.352941  289.705882  53.058824   50.352941   55.411765
# 1     Bug-Electric  595.500000  395.500000  60.000000   62.000000   55.000000
# 2     Bug-Fighting  214.000000  550.000000  80.000000  155.000000   95.000000
# 3         Bug-Fire  636.500000  455.000000  70.000000   72.500000   60.000000
# 4       Bug-Flying  286.285714  419.500000  63.000000   70.142857   61.571429
# ..             ...         ...         ...        ...         ...         ...
# ...

# %%
poke_mean[poke_mean['Combo Type'].isin(list_combotypes)]
# Out:
#      Combo Type           #       Total         HP      Attack     Defense  \
# 8    Bug-Poison  199.166667  347.916667  53.750000   68.333333   58.083333
# 109    Psychic-  381.973684  464.552632  72.552632   64.947368   67.236842
# 117       Rock-  410.111111  409.444444  67.111111  103.333333  107.222222
# 140  Water-Dark  347.666667  493.833333  69.166667  120.000000   65.166667
#
#        Sp. Atk    Sp. Def      Speed  Generation  Legendary  A/D Ratio
# 8    42.500000  59.333333  65.916667    2.333333   0.000000   1.315989
# 109  98.552632  82.394737  78.868421    3.342105   0.236842   1.164196
# 117  40.555556  58.333333  32.888889    3.888889   0.111111   1.260091
# 140  88.833333  63.500000  87.166667    3.166667   0.000000   2.291949
