# %%
import pandas as pd
import numpy as np

# %%
pokemon = pd.read_csv("pokemon.csv")
pokemon
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# 1         80       80     60           1      False
# 2        100      100     80           1      False
# 3        122      120     80           1      False
# 4         60       50     65           1      False
# ..       ...      ...    ...         ...        ...
# 795      100      150     50           6       True
# 796      160      110    110           6       True
# 797      150      130     70           6       True
# 798      170      130     80           6       True
# 799      130       90     70           6       True
#
# [800 rows x 13 columns]

# %%
def compute_total(pokemon):
    if ['HP']+['Attack']+['Defense']+['Sp. Atk']+['Sp. Def']+['Speed'] == ['Total']:
        return 'True'
    else:
        return 'False'

pokemon_total = compute_total(pokemon)
display(pokemon_total)
# Out:
# 'False'

# %%
from sklearn.preprocessing import OneHotEncoder
pokemon = OneHotEncoder()
pokemon
# Out:
# OneHotEncoder()

# %%
from sklearn.preprocessing import OneHotEncoder
#encoder = OneHotEncoder().
encoder = OneHotEncoder(['Type 1'])
print(encoder)
# encoded = encoder.transform(X_cat).toarray()
# print(encoded)
# #onehot_encoded = pd.DataFrame(encoded,columns=['Female', 'Male','U'])
# onehot_encoded = pd.pokemon(encoded,columns=['Type 1', 'Type 2'])
# onehot_encoded.head(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 3
#       1 from sklearn.preprocessing import OneHotEncoder
#       2 #encoder = OneHotEncoder().
# ----> 3 encoder = OneHotEncoder(['Type 1'])
#       4 print(encoder)
#
# TypeError: OneHotEncoder.__init__() takes 1 positional argument but 2 were given

# %%
#label encoding keeps just one column and makes it numerical, but watch out: you may be introducing unintended semantics
#if you want to control which number gets assigned to which category, you can use OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
label_encoded = LabelEncoder().fit(X_cat).transform(X_cat) # ordered wrt value counts
label_encoded = pd.DataFrame(label_encoded,columns=X_cat.columns)
display(label_encoded.head(20))
label_encoded['gender'].value_counts()
